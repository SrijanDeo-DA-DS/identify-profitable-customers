# %%
import pandas as pd
import numpy as np
import pickle
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pickle.load(open('C:/Users/Srijan-DS/Documents/Projects/identify-profitable-customers/artifacts/data.pkl','rb'))

pipe = pickle.load(open('C:/Users/Srijan-DS/Documents/Projects/identify-profitable-customers/artifacts/fe_pipe.pkl','rb'))

model = pickle.load(open('C:/Users/Srijan-DS/Documents/Projects/identify-profitable-customers/artifacts/model.pkl','rb'))

# %%
df.head()
# Out:
#    job_type_Self employed  purchase_amount    area personal_card_2  \
# 0                     0.0          62978.0  2994.0             0.0
# 1                     0.0          66790.0  5318.0             0.0
# 2                     1.0          57788.0  5954.0             0.0
# 3                     1.0          59729.0  7263.0             0.0
# 4                     1.0          50533.0  6270.0             0.0
#
#   personal_card_4 campaign_use card_expired score_4  asset_amount  \
# 0             1.0          0.0          0.0     0.0         64016
# 1             0.0          0.0          0.0     0.0         64497
# 2             0.0          2.0          1.0     0.0        111404
# 3             0.0          0.0          0.0     0.0         63983
# 4             0.0          0.0          0.0     0.0         98623
#
#    average_ratio  personal_id_1  personal_id_2  age  phone  personal_card_1  \
# 0      87.170255           1256             86   44      1                1
# 1      83.609102            666             86   30      1                0
# 2      58.986180           1621            120   36      1                1
# 3      72.702121           1731             51   27      1                0
# 4      82.218856            801             86   40      1                1
#
#    personal_card_3  car  purchase_score  average_favorite_score  \
# 0                0    0               0                0.010922
# 1                1    0             705                1.687598
# 2                0    0             309                0.001265
# 3                0    0             740                0.015441
# 4                0    0               3                0.001283
#
#    card_history_period  score_1  score_2  score_3  total_amount_1  \
# 0             0.048340        0        7        0           58620
# 1             1.701259        0        0        6           70809
# 2             3.483625        0        9        6           55294
# 3             3.338835        0        1        2            1972
# 4             0.067355        0        2        0            4942
#
#    total_amount_2  total_amount_3
# 0           10590            1392
# 1            9575             889
# 2           38319             779
# 3            9314            2081
# 4           10484            1772

# %%
df_transformed = pipe.transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_transformed = pipe.transform(df)
#
# File ~\anaconda3\Lib\site-packages\sklearn\pipeline.py:696, in Pipeline.transform(self, X)
#     694 Xt = X
#     695 for _, _, transform in self._iter():
# --> 696     Xt = transform.transform(Xt)
#     697 return Xt
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:821, in ColumnTransformer.transform(self, X)
#     819     diff = all_names - set(X.columns)
#     820     if diff:
# --> 821         raise ValueError(f"columns are missing: {diff}")
#     822 else:
#     823     # ndarray was used for fitting or transforming, thus we only
#     824     # check that n_features_in_ is consistent
#     825     self._check_n_features(X, reset=False)
#
# ValueError: columns are missing: {'important_customer'}
